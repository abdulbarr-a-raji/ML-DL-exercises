# %%
from keras import layers, models
from keras.utils import to_categorical

# %%
# Define our CNN model
model = models.Sequential()
model.add(layers.Conv2D(32, (5,5), activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Conv2D(64, (5,5), activation='relu'))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Flatten())
model.add(layers.Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 32)        832
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 64)          51264
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 10)                10250
#
# =================================================================
# Total params: 62,346
# Trainable params: 62,346
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.datasets import mnist

# Split MNIST dataset into training & testing datasets
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images.reshape((60000,28,28,1)).astype('float32')/255
test_images = test_images.reshape((10000,28,28,1)).astype('float32')/255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# Compile & Fit the model
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
model.fit(train_images, train_labels, batch_size=100, epochs=5, verbose=1)
# Out:
# Epoch 1/5
# 600/600 [==============================] - 47s 77ms/step - loss: 0.9030 - accuracy: 0.7676
# Epoch 2/5
# 600/600 [==============================] - 40s 67ms/step - loss: 0.2689 - accuracy: 0.9215
# Epoch 3/5
# 600/600 [==============================] - 39s 66ms/step - loss: 0.1941 - accuracy: 0.9435
# Epoch 4/5
# 600/600 [==============================] - 39s 65ms/step - loss: 0.1550 - accuracy: 0.9554
# Epoch 5/5
# 600/600 [==============================] - 41s 68ms/step - loss: 0.1312 - accuracy: 0.9620

# %%
# Test the model
test_loss, test_acc = model.evaluate(test_images, test_labels)

print(test_loss)
print('\n')
print(test_acc)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1109 - accuracy: 0.9684
# 0.11086353659629822
#
#
# 0.9684000015258789
